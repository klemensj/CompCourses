# %%
import numpy as np
import pandas as pan

TYLER_control = pan.read_csv('TYLER_control.txt', sep ='\t', skiprows=6, names = ["interval","data"])
TYLER_scared = pan.read_csv('TYLER_scared.txt', sep ='\t', skiprows=6, names = ["interval","data"])
NOA_control = pan.read_csv('NOA_control.txt', sep ='\t', skiprows=6, names = ["interval","data"])
NOA_scared = pan.read_csv('NOA_scared.txt', sep ='\t', skiprows=6, names = ["interval","data"])

# %%
TYLER_control.head()
TYLER_scared.head()
NOA_control.head()
NOA_scared.head()
# Out:
#    interval      data
# 0     0.000 -14.79688
# 1     0.001 -15.40625
# 2     0.002 -14.20312
# 3     0.003 -14.34375
# 4     0.004 -13.12500

# %%
FearData = pan.concat([NOA_control['data'], NOA_scared['data'], TYLER_control['data'], TYLER_scared['data']], ignore_index = True, axis=1,)

# %%
FearData.columns=["NOA_control","NOA_scared","TYLER_control","TYLER_scared"]
FearData.head()
# Out:
#   NOA_control  NOA_scared  TYLER_control  TYLER_scared
# 0   -11.07812   -14.79688       1.953125     -0.062500
# 1   -11.85938   -15.40625       2.015625     -0.140625
# 2   -11.10938   -14.20312       1.812500     -0.250000
# 3   -11.48438   -14.34375       1.750000     -0.390625
# 4   -11.03125   -13.12500       1.593750     -0.515625

# %%
FearData
# Out:
#       NOA_control  NOA_scared  TYLER_control  TYLER_scared
# 0       -11.07812   -14.79688       1.953125     -0.062500
# 1       -11.85938   -15.40625       2.015625     -0.140625
# 2       -11.10938   -14.20312       1.812500     -0.250000
# 3       -11.48438   -14.34375       1.750000     -0.390625
# 4       -11.03125   -13.12500       1.593750     -0.515625
# 5       -11.10938   -12.70312       1.562500     -0.625000
# 6       -10.90625   -12.20312       1.484375     -0.750000
# 7       -10.84375   -11.84375       1.453125     -0.875000
# 8          -10.75   -11.31250       1.359375     -1.000000
# 9       -10.65625   -11.12500       1.296875     -1.125000
# 10      -10.53125   -10.85938       1.250000     -1.265625
# 11      -10.34375   -10.59375       1.218750     -1.406250
# 12        -10.125   -10.54688       1.156250     -1.578125
# 13         -9.875   -10.53125       1.078125     -1.734375
# 14         -9.625   -10.87500       0.984375     -1.875000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
mat.style.use('dark_background')
import numpy as num

# %%
fig = plt.figure()
ax = plt.axes()
mat.plot([0,200,400,600,800,1000], color='blue')
ax.set(xlim=(0, 1000), ylim=(-30,50),
       xlabel='Time', ylabel='Electrical Impulse',
       title='Fear Data');

mat.plot(TYLER_control),
mat.plot(TYLER_scared),
#mat.plot(NOA_control),
mat.plot(NOA_scared);
